# %% [markdown]
# <a href="https://colab.research.google.com/github/ezengels/JuiceAcademyWeek4/blob/main/Copy_of_Week_1_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 1 Homework
#
# (Be sure to save this to Drive before starting)
#
# For this week we are going to practice requesting information from an API and manipulating it as JSON and as a Dataframe.
#
# We are going to keep working with Collection Builder. Head over to the [Collection Builder Example Projects](https://collectionbuilder.github.io/cb-examples/browse.html) listing and find a site that interests you. Spend some time browsing the website to get acquainted with its contents before proceeding with the questions.

# %%
#The Libraries we will need
import requests
import json
import pandas as pd
from random import randrange

# %%
# @markdown **H1** Find the URL of for the  _metadata.json_ of your selected site and paste it in here.
json_cb_url = "https://wangj619.github.io/babylonianelites/assets/data/metadata.json" # @param {"type":"string","placeholder":""}

response_cb = requests.get(json_cb_url)
#all of the data from the sites
total_cb_data = response_cb.json()
#just the 'objects' indexed in the site
objects_cb_data = total_cb_data['objects']
print("Data fetched and JSON constructed!")
# Out:
# Data fetched and JSON constructed!

# %% [markdown]
# **H2** Run the 'show random cell' a few times to get a sense of what kind of data is in your chosen site.

# %%
#Run this a few times to see random entries in the JSON data that you retrieved.
random_entry = randrange(len(objects_cb_data))
print(json.dumps(objects_cb_data[random_entry],indent=2))
# Out:
# {
#   "title": "Families",
#   "date": "2022",
#   "subject": "Family",
#   "location": "Babylon",
#   "latitude": "32.53737187",
#   "longitude": "44.42467434",
#   "type": "Image;StillImage",
#   "format": "image/jpeg",
#   "language": "eng",
#   "reference_url": "https://wangj619.github.io/babylonianelites/item.html?id=coll004"
# }

# %% [markdown]
# ## Different Fields!
#
# You can create any number of datafields and correpsonding values for those fields with a Collection Builder site. So the results from the output from the cell above will probably have wildly different results from [my site](https://elibtronic.github.io/AIL_Database/data.html) that we worked on in the Workalong notebook.
#
#
# You can see all of these options from grabbing the _facets.json_ URL from a collection builder homepage. Find that URL for your selected site for **H3**

# %%
# @markdown **H3** Find the URL of the facets.json for your selected site and paste it in here.
json_cb_facets_url = "https://wangj619.github.io/babylonianelites/assets/data/facets.json" # @param {"type":"string","placeholder":""}

response_cb = requests.get(json_cb_facets_url)
#all of the data from the sites
total_facet_data = response_cb.json()
#just the 'objects' indexed in the site
print("Data fetched and JSON constructed!")
# Out:
# Data fetched and JSON constructed!

# %% [markdown]
# Run the cell below to see what the facets used for this site:

# %%
print(json.dumps(total_facet_data,indent=2))
# Out:
# {
#   "facets": [
#     {
#       "field": "subject",
#       "terms": {
#         "archive": 2,
#         "central figures": 2,
#         "family": 1,
#         "gender": 2,
#         "social division": 1,
#         "social integration": 1
#       }
#     },
#     {
#       "field": "creator",
#       "terms": {}
#     },
#     {
#       "field": "format",
#       "terms": {
#         "image/jpeg": 9
#       }
#     }
#   ]
# }

# %% [markdown]
# **H3** Try to read the JSON that is displayed to the screen. What possible facets are there in the the data. Fill them in the markdown list in the cell below. Add as many entries as you need to describe the site

# %% [markdown]
# Facets in my site are:
# - subject; includes archive, central figures, family, gender, social division, and social integration
# - creator; has no terms, not used by collection creator
# - format; image/jpeg

# %% [markdown]
# **H4** Which facet shows up the most for your selected site? Put your answer in the cell below

# %% [markdown]
# Both the field and subject facets are used 9 times. The facet term used the most is "image/jpeg" for format, which is used 9 times.

# %% [markdown]
# **H5** Turn the site _metadata.json_ data into a dataframe by completing the cell below. Part of it is written for you. You just need to modify line 4.

# %%
#H5

cb_data = pd.read_json(json_cb_url)
cb_normalized = pd.json_normalize(cb_data['objects'])
cb_normalized
# Out:
#                            title  date             subject location  \
# 0                  Core (Gender)  2022              Gender  Babylon
# 1                       Archives  2022             Archive  Babylon
# 2                Social Division  2022     Social Division  Babylon
# 3                       Families  2022              Family  Babylon
# 4  Central Figures (Betweenness)  2022     Central Figures  Babylon
# 5       Central Figures (Degree)  2022     Central Figures  Babylon
# 6             Social Integration  2022  Social Integration  Babylon
# 7         Whole Network (Gender)  2022              Gender  Babylon
# 8                  Whole Network  2022             Archive  Babylon
#
#       latitude    longitude              type      format language  \
# 0  32.53737187  44.42467434  Image;StillImage  image/jpeg      eng
# 1  32.53737187  44.42467434  Image;StillImage  image/jpeg      eng
# 2  32.53737187  44.42467434  Image;StillImage  image/jpeg      eng
# 3  32.53737187  44.42467434  Image;StillImage  image/jpeg      eng
# 4  32.53737187  44.42467434  Image;StillImage  image/jpeg      eng
# 5  32.53737187  44.42467434  Image;StillImage  image/jpeg      eng
# 6  32.53737187  44.42467434  Image;StillImage  image/jpeg      eng
# 7  32.53737187  44.42467434  Image;StillImage  image/jpeg      eng
# 8  32.53737187  44.42467434  Image;StillImage  image/jpeg      eng
#
#                                        reference_url
# 0  https://wangj619.github.io/babylonianelites/it...
# 1  https://wangj619.github.io/babylonianelites/it...
# 2  https://wangj619.github.io/babylonianelites/it...
# 3  https://wangj619.github.io/babylonianelites/it...
# 4  https://wangj619.github.io/babylonianelites/it...
# 5  https://wangj619.github.io/babylonianelites/it...
# 6  https://wangj619.github.io/babylonianelites/it...
# 7  https://wangj619.github.io/babylonianelites/it...
# 8  https://wangj619.github.io/babylonianelites/it...

# %%
#Run this a few times to see random entries in your dataframe
cb_normalized.sample(1)
# Out:
#                 title  date             subject location     latitude  \
# 6  Social Integration  2022  Social Integration  Babylon  32.53737187
#
#      longitude              type      format language  \
# 6  44.42467434  Image;StillImage  image/jpeg      eng
#
#                                        reference_url
# 6  https://wangj619.github.io/babylonianelites/it...

# %% [markdown]
# **H6** This is for bonus!
# Try to write a pandas statement that will display your answer from **H4**. There are plenty of ways to do this, so feel free to use your imagination. What I have started for you here might not work, so feel free to change it as needed.

# %%
cb_facet_data = pd.read_json(json_cb_facets_url)
cb_facet_data = pd.json_normalize(cb_facet_data['facets'])
cb_facet_data
# Out:
#      field  terms.archive  terms.central figures  terms.family  terms.gender  \
# 0  subject            2.0                    2.0           1.0           2.0
# 1  creator            NaN                    NaN           NaN           NaN
# 2   format            NaN                    NaN           NaN           NaN
#
#    terms.social division  terms.social integration  terms.image/jpeg
# 0                    1.0                       1.0               NaN
# 1                    NaN                       NaN               NaN
# 2                    NaN                       NaN               9.0

# %%
print(cb_facet_data.max())
# Out:
# field                       subject
# terms.archive                   2.0
# terms.central figures           2.0
# terms.family                    1.0
# terms.gender                    2.0
# terms.social division           1.0
# terms.social integration        1.0
# terms.image/jpeg                9.0
# dtype: object

# %% [markdown]
# As can be seen, the term "image/jpeg" is used the most out of the facets/terms.

# %% [markdown]
# ## All Done!
#
# Congrats you are finished with this week's work. First save as PDF so that you can upload to the Course site then click the `Share` button above and enter `libraryjuicepresspython@gmail.com` so I can get a shared copy of your work.
